# %% [markdown]
# <a href="https://colab.research.google.com/github/erika-munho/TalentoTech/blob/main/Regresion_Simple_Multiple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ANALISIS DE REGRESION SIMPLE Y MULTIPLE**
#
# Se empleará el dataset World Happiness Report para realizar el analisis de regresion simple y multiple.Se tomara como variable dependiente "y" la columna Score, que indica la puntuacion de la felicidad en funcion de variables independientes como economic production, social support, life expectancy, freedom, absence of corruption, and generosity.

# %%
import pandas as pd
import sklearn
import seaborn as sns
import numpy as np

# %%
df_Happiness = pd.read_csv("Felicidad_Mundial_2019.csv")
df_Happiness.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
df_Happiness.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# 25%                   0.547750                      0.308000    0.108750
# 50%                   0.789000                      0.417000    0.177500
# 75%                   0.881750                      0.507250    0.248250
# max                   1.141000                      0.631000    0.566000
#
#        Perceptions of corruption
# count                 156.000000
# mean                    0.110603
# std                     0.094538
# min                     0.000000
# 25%                     0.047000
# 50%                     0.085500
# 75%                     0.141250
# max                     0.453000

# %% [markdown]
# # Modelo de regresion 1 variable

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# extrayendo la información del dataset
X = df_Happiness[["GDP per capita"]]
y = df_Happiness["Score"]

# particionando en dos conjuntos _train y _test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# crear el modelo
model = LinearRegression(fit_intercept = True)

# entrenarlo con los datos
model.fit(X_train, y_train)

# se pueden mostrar con la función print
print(f"La pendiente del modelo (B) es: {model.coef_}, el intersepto (A) es {model.intercept_}")

y_pred = model.predict(X_test)
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, model.predict(X_train), color = 'red')
plt.ylabel('Score')
plt.xlabel('Healthy life expectancy')
plt.title('Happiness Score in relation to Healthy life expectancy')

# Realizar predicciones en el conjunto de datos
y_pred = model.predict(X_test)

# Calcular metricas de rendimiento
mse = mean_squared_error(y_test,y_pred)

rmse = mse**0.5

r2 = r2_score(y_test,y_pred)

print("Error cuadratico medio(MSE):",mse)
print("Raiz error cuadratico medio:",rmse)
print("Coeficiente de determinacion (R^2):",r2)
# Out:
# La pendiente del modelo (B) es: [2.32863081], el intersepto (A) es 3.2821317984689866
# Error cuadratico medio(MSE): 0.42737917509045303
# Raiz error cuadratico medio: 0.6537424378839521
# Coeficiente de determinacion (R^2): 0.5764890254626995

# %% [markdown]
# # Modelo de regresion 2 variables

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# extrayendo la información del dataset
X = df_Happiness[["Healthy life expectancy","GDP per capita",]]
y = df_Happiness["Score"]

# particionando en dos conjuntos _train y _test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# crear el modelo
model = LinearRegression(fit_intercept = True)

# entrenarlo con los datos
model.fit(X_train, y_train)

# se pueden mostrar con la función print
print(f"La pendiente del modelo (B) es: {model.coef_}, el intersepto (A) es {model.intercept_}")

# Realizar predicciones en el conjunto de datos
y_pred = model.predict(X_test)

# Calcular metricas de rendimiento
mse = mean_squared_error(y_test,y_pred)

rmse = mse**0.5

r2 = r2_score(y_test,y_pred)

print("Error cuadratico medio(MSE):",mse)
print("Raiz error cuadratico medio:",rmse)
print("Coeficiente de determinacion (R^2):",r2)

# Estandarizar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Graficar los resultados
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.xlabel('Healthy life expectancy')
plt.ylabel('GDP per capita')
plt.title('Happiness Score in relation to Healthy life expectancy and GDP')
plt.colorbar(label='Score')
plt.show()
# Out:
# La pendiente del modelo (B) es: [1.7285756  1.33455889], el intersepto (A) es 2.9480686842936974
# Error cuadratico medio(MSE): 0.42815557898719386
# Raiz error cuadratico medio: 0.654335983258749
# Coeficiente de determinacion (R^2): 0.6663254288502547

# %% [markdown]
# # Modelo de regresion 3 variables

# %%
# extrayendo la información del dataset
X = df_Happiness[["Healthy life expectancy","GDP per capita","Generosity"]]
y = df_Happiness["Score"]

# particionando en dos conjuntos _train y _test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# crear el modelo
model = LinearRegression(fit_intercept = True)

# entrenarlo con los datos
model.fit(X_train, y_train)

# se pueden mostrar con la función print
print(f"La pendiente del modelo (B) es: {model.coef_}, el intersepto (A) es {model.intercept_}")

# Realizar predicciones en el conjunto de datos
y_pred = model.predict(X_test)

# Calcular metricas de rendimiento
mse = mean_squared_error(y_test,y_pred)

rmse = mse**0.5

r2 = r2_score(y_test,y_pred)

print("Error cuadratico medio(MSE):",mse)
print("Raiz error cuadratico medio:",rmse)
print("Coeficiente de determinacion (R^2):",r2)

# Estandarizar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Graficar los resultados
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.xlabel('Generosity')
plt.ylabel('GDP per capita')
plt.title('Happiness Score in relation to Healthy life expectancy and Generosity')
plt.colorbar(label='Score')
plt.show()
# Out:
# La pendiente del modelo (B) es: [1.50457765 1.4520243  1.88903444], el intersepto (A) es 2.639112574317525
# Error cuadratico medio(MSE): 0.45883133679206084
# Raiz error cuadratico medio: 0.6773709004615277
# Coeficiente de determinacion (R^2): 0.6611831475252256

# %% [markdown]
# # Modelo de regresion 4 variables

# %%
# extrayendo la información del dataset
X = df_Happiness[["Social support","Freedom to make life choices","Generosity","Perceptions of corruption"]]
y = df_Happiness["Score"]

# particionando en dos conjuntos _train y _test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# crear el modelo
model = LinearRegression(fit_intercept = True)

# entrenarlo con los datos
model.fit(X_train, y_train)

# se pueden mostrar con la función print
print(f"La pendiente del modelo (B) es: {model.coef_}, el intersepto (A) es {model.intercept_}")

# Realizar predicciones en el conjunto de datos
y_pred = model.predict(X_test)

# Calcular metricas de rendimiento
mse = mean_squared_error(y_test,y_pred)

rmse = mse**0.5

r2 = r2_score(y_test,y_pred)

print("Error cuadratico medio(MSE):",mse)
print("Raiz error cuadratico medio:",rmse)
print("Coeficiente de determinacion (R^2):",r2)
# Out:
# La pendiente del modelo (B) es: [2.54033114 1.08430336 0.54931712 2.93701144], el intersepto (A) es 1.4722772400215276
# Error cuadratico medio(MSE): 0.460387393791269
# Raiz error cuadratico medio: 0.6785185287015153
# Coeficiente de determinacion (R^2): 0.32230939071247

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Estandarizar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Graficar los resultados
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.xlabel('Social support')
plt.ylabel('Generosity')
plt.title('Resultados de PCA')
plt.colorbar(label='Score')
plt.show()
