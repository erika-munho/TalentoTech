# %% [markdown]
# <a href="https://colab.research.google.com/github/erika-munho/TalentoTech/blob/main/Actividad_1_Visualizaci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# carga de paquetes y funciones para generar gráficos
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install numpy

# %%
import numpy as np

# %%
rango = np.random.RandomState(0)

# %%
x = np.linspace(0, 10, 500)
y = np.cumsum (rango.randn (500, 6), 0)

# %%
# Graficar los datos
plt.plot (x,y)
plt.legend ('ABCDEF', ncol=2, loc='upper left');

# %%
sns.set() #Carga de estilos de seaborn
#luego se dibuja exactamente igual que en el
#codigo anterior
plt.plot(x,y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
# Generando puntos de una funcion
x_val = np.linspace (0,10,20)
y_val = x_val ** 2
plt.scatter(x_val, y_val)

# %% [markdown]
# \La grafica anterior, muestra una funcion no lineal, ya que es el resultado de una función cuadratica, y se presenta con la forma de parabola

# %%
plt.scatter(x_val, y_val)
plt.title ("Desplazamiento") #Titulo del grafico
plt.xlabel ("Tiempo[segundos]") #Etiqueta del eje x
plt.ylabel ("Distancia [metros]") #Etiqueta del eje y
# Out:
# Text(0, 0.5, 'Distancia [metros]')

# %%
plt.scatter(x_val, y_val, marker='*')
plt.title ("Desplazamiento") #Titulo del grafico
plt.xlabel ("Tiempo[segundos]") #Etiqueta del eje x
plt.ylabel ("Distancia [metros]") #Etiqueta del eje y
# Out:
# Text(0, 0.5, 'Distancia [metros]')

# %%
plt.scatter(x_val, y_val, marker='*', color='g')
plt.title ("Desplazamiento") #Titulo del grafico
plt.xlabel ("Tiempo[segundos]") #Etiqueta del eje x
plt.ylabel ("Distancia [metros]") #Etiqueta del eje y
# Out:
# Text(0, 0.5, 'Distancia [metros]')

# %%
plt.plot(x_val, y_val, color='r')
plt.scatter(x_val, y_val, marker=',', color='g', s=150)
plt.title ("Desplazamiento") #Titulo del grafico
plt.xlabel ("Tiempo[segundos]") #Etiqueta del eje x
plt.ylabel ("Distancia [metros]") #Etiqueta del eje y
# Out:
# Text(0, 0.5, 'Distancia [metros]')

# %% [markdown]
# HISTOGRAMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
# Uso de función multivariate_normal de la biblioteca NumPy para generar datos aleatorios de una distribución normal multivariada
# argumentos media [0,0], matriz de covarianza [[5,2],[2,2]], tamano de muestra size 2000
data = pd.DataFrame(data, columns=['x', 'y'])
for col in 'xy':
      plt.hist(data[col], alpha=0.5)

# %% [markdown]
# La grafica anterios evidencia que los datos de 'x' y 'y' presentan una distribucion normal, se observa que valores positivos y negativos son igualmente probables, ya que la distribucion es simetrica respecto a la media cero, ademas la distribucion presenta forma gausiana, por tanto la distribución es normal. La distribución de datos respresentados por el color rojo presentan una densidad levemente mayor, que la distribución de datos en color rojo, ya que los datos de la primera están mas concentrados respecto a la media, que se ubica al rededor de cero

# %%
for col in 'xy':
  sns.kdeplot(data[col], shade=True)
# Out:
# <ipython-input-15-09e8282ff3fb>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# <ipython-input-15-09e8282ff3fb>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)

# %%
for col in 'xy':
  sns.kdeplot(data[col], fill=True)

# %%
sns.distplot(data['x'])
sns.distplot(data['y'])
# Out:
# <ipython-input-17-bc00d6c58455>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['x'])
# <ipython-input-17-bc00d6c58455>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['y'])
# <Axes: xlabel='y', ylabel='Density'>

# %% [markdown]
# En esta gráfica con dos distribuciones se observa par ambas una distribucion normal o gausiana, explicada por la simetria de distribucion de los datos con respecto a la media, con la diferencia que una de ellas (curva color naranja) presenta un valor mas concentrado en comparación a la distribución en coloración azul muestra una dispersion de datos levemente mayor con respecto a la media, evidenciado en la anchura de la campana. Ambas tienen una media al rededor de cero. La curva naranja presenta una distribución estandar menor porque no se va hacia los extremos, lo que indica una densidad mayor que la distribución identificada con el color azul, que tiende a prolongarse hacia los extremos, lo que indica una distribución estandar mas grande, por tanto la distribución en torno a la media no es tan estrecha si se compara con la curva de color naranja

# %%
sns.displot(data['x'])
sns.displot(data['y'])

# %%
sns.histplot(data['x'])
sns.histplot(data['y'])
# Out:
# <Axes: xlabel='x', ylabel='Count'>

# %% [markdown]
# Replicating basic distplot output, acording: https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
sns.histplot(data['x'], kde=True, stat="density")
sns.histplot(data['y'], kde=True, stat="density")
# Out:
# <Axes: xlabel='x', ylabel='Density'>

# %% [markdown]
# **ANALISI GRAFICO**

# %%
iris = sns.load_dataset("iris")
iris.head()
sns.pairplot(iris, hue='species', size=2.5);
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Con los datos de la figura anterior es posible mostrar que el ancho de pétalos permite separar las especies fácilmente, también es posible ver que esta situación se parece al largo del pétalo. Sin embargo se ve que con el ancho del sépalo no es fácil dividir las flores por tipo, asi mismo el largo del sepalo tampoco permite clasificar estas especies con facilidad.
#
# Al analizar la característica referente al ancho de los pétalos se observa que la flor setosa presenta una menor disperción de los datos respecto de la media cuyo valor aproximado es 0.3 aproximadamente, por tanto mayor densidad en comparación a las gráficas de distribución de la flores versicolor y virginica

# %%
iris["species"]=="versicolor"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: species, Length: 150, dtype: bool

# %% [markdown]
# **CONSULTAR Como mostrar todas las columnas y todas las filas de un data set

# %%
# Para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Para mostrar todas las filas
pd.set_option('display.max_rows', None)

# Mostrar todas las filas y columnas del conjunto de datos 'iris'
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...
